# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import sklearn 
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score, mean_squared_error

# %%
df = pd.read_csv('weatherHistory.csv')

df
# Out:
#                       Formatted Date  ...                           Daily Summary
# 0      2006-04-01 00:00:00.000 +0200  ...       Partly cloudy throughout the day.
# 1      2006-04-01 01:00:00.000 +0200  ...       Partly cloudy throughout the day.
# 2      2006-04-01 02:00:00.000 +0200  ...       Partly cloudy throughout the day.
# 3      2006-04-01 03:00:00.000 +0200  ...       Partly cloudy throughout the day.
# 4      2006-04-01 04:00:00.000 +0200  ...       Partly cloudy throughout the day.
# ...                              ...  ...                                     ...
# 96448  2016-09-09 19:00:00.000 +0200  ...  Partly cloudy starting in the morning.
# 96449  2016-09-09 20:00:00.000 +0200  ...  Partly cloudy starting in the morning.
# 96450  2016-09-09 21:00:00.000 +0200  ...  Partly cloudy starting in the morning.
# 96451  2016-09-09 22:00:00.000 +0200  ...  Partly cloudy starting in the morning.
# ...

# %%
df.isnull().sum()
# Out:
# Formatted Date                0
# Summary                       0
# Precip Type                 517
# Temperature (C)               0
# Apparent Temperature (C)      0
# Humidity                      0
# Wind Speed (km/h)             0
# Wind Bearing (degrees)        0
# Visibility (km)               0
# Loud Cover                    0
# Pressure (millibars)          0
# Daily Summary                 0
# dtype: int64

# %%
df.head(5)
# Out:
#                   Formatted Date  ...                      Daily Summary
# 0  2006-04-01 00:00:00.000 +0200  ...  Partly cloudy throughout the day.
# 1  2006-04-01 01:00:00.000 +0200  ...  Partly cloudy throughout the day.
# 2  2006-04-01 02:00:00.000 +0200  ...  Partly cloudy throughout the day.
# 3  2006-04-01 03:00:00.000 +0200  ...  Partly cloudy throughout the day.
# 4  2006-04-01 04:00:00.000 +0200  ...  Partly cloudy throughout the day.
#
# [5 rows x 12 columns]

# %%
# Vẽ biểu đồ scatter với đường xu hướng tuyến tính
plt.scatter(df['Humidity'], df['Temperature (C)'])
plt.xlabel('Độ ẩm')
plt.ylabel('Nhiệt độ')
plt.title('Mối quan hệ giữa độ ẩm và nhiệt độ')
plt.plot(df['Humidity'], np.poly1d(np.polyfit(df['Humidity'], df['Temperature (C)'], 1))(df['Humidity']), color='red')
plt.show()

# %%
df.isna().sum()
# Out:
# Formatted Date                0
# Summary                       0
# Precip Type                 517
# Temperature (C)               0
# Apparent Temperature (C)      0
# Humidity                      0
# Wind Speed (km/h)             0
# Wind Bearing (degrees)        0
# Visibility (km)               0
# Loud Cover                    0
# Pressure (millibars)          0
# Daily Summary                 0
# dtype: int64

# %%
df['Precip Type'].fillna('Unknown', inplace=True)

df
# Out:
# C:\Users\T14\AppData\Local\Temp\ipykernel_14736\135032179.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Precip Type'].fillna('Unknown', inplace=True)
#                       Formatted Date  ...                           Daily Summary
# 0      2006-04-01 00:00:00.000 +0200  ...       Partly cloudy throughout the day.
# 1      2006-04-01 01:00:00.000 +0200  ...       Partly cloudy throughout the day.
# 2      2006-04-01 02:00:00.000 +0200  ...       Partly cloudy throughout the day.
# ...

# %%
X = df['Humidity'].values.reshape(-1,1)
y = df['Temperature (C)'].values

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
model = LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
# Dự đoán
y_pred = model.predict(X_test)

# %%
r2_score = r2_score(y_test, y_pred)
rmse = np.sqrt(mean_squared_error(y_test, y_pred))

print('Result: ')
print('R-squared: {r2_score:.4f}')
print('RMSE: {rmse:.4f}')
# Out:
# Result:
# R-squared: {r2_score:.4f}
# RMSE: {rmse:.4f}
